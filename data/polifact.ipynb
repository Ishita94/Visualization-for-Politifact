# %%
import os

# %matplotlib inline
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from pandas_profiling import ProfileReport
from datetime import datetime

# %%
df = pd.read_json('politifact_factcheck_data.json', lines=True)
df
# Out:
#             verdict statement_originator  \
# 0              true         Barack Obama
# 1             false           Matt Gaetz
# 2       mostly-true         Kelly Ayotte
# 3             false             Bloggers
# 4         half-true         Bobby Jindal
# ...             ...                  ...
# 21147  mostly-false         Donald Trump
# 21148         false     Donald Trump Jr.
# 21149  mostly-false          Chris Abele
# 21150         false             Bloggers
# 21151  mostly-false       Facebook posts
#
#                                                statement statement_date  \
# 0      John McCain opposed bankruptcy protections for...      6/11/2008
# 1      "Bennie Thompson actively cheer-led riots in t...       6/7/2022
# 2      Says Maggie Hassan was "out of state on 30 day...      5/18/2016
# 3      "BUSTED: CDC Inflated COVID Numbers, Accused o...       2/1/2021
# 4      "I'm the only (Republican) candidate that has ...      8/30/2015
# ...

# %%
# Only keep statements made by statement_originator of >= 10 statements
is_multi = df["statement_originator"].value_counts() >= 10
filtered = df[df["statement_originator"].isin(is_multi[is_multi].index)]

# Drop any duplicates
filtered = filtered.drop_duplicates()

# Reset index
filtered = filtered.reset_index(drop=True)

filtered
# Out:
#             verdict statement_originator  \
# 0              true         Barack Obama
# 1             false           Matt Gaetz
# 2       mostly-true         Kelly Ayotte
# 3             false             Bloggers
# 4         half-true         Bobby Jindal
# ...             ...                  ...
# 13235  mostly-false         Donald Trump
# 13236         false     Donald Trump Jr.
# 13237  mostly-false          Chris Abele
# 13238         false             Bloggers
# 13239  mostly-false       Facebook posts
#
#                                                statement statement_date  \
# 0      John McCain opposed bankruptcy protections for...      6/11/2008
# 1      "Bennie Thompson actively cheer-led riots in t...       6/7/2022
# 2      Says Maggie Hassan was "out of state on 30 day...      5/18/2016
# 3      "BUSTED: CDC Inflated COVID Numbers, Accused o...       2/1/2021
# 4      "I'm the only (Republican) candidate that has ...      8/30/2015
# ...

# %%
#prof = ProfileReport(filtered)
#prof.to_file(output_file='output_filtered.html') # Get the report to a seprate html file

# %%
# encode verdicts to int
filtered['verdict'].replace(to_replace=['pants-fire', 'false', 'mostly-false', 'half-true', 'mostly-true', 'true'], value=[0,1,2,3,4,5], inplace=True)
filtered
# Out:
#        verdict statement_originator  \
# 0            5         Barack Obama
# 1            1           Matt Gaetz
# 2            4         Kelly Ayotte
# 3            1             Bloggers
# 4            3         Bobby Jindal
# ...        ...                  ...
# 13235        2         Donald Trump
# 13236        1     Donald Trump Jr.
# 13237        2          Chris Abele
# 13238        1             Bloggers
# 13239        2       Facebook posts
#
#                                                statement statement_date  \
# 0      John McCain opposed bankruptcy protections for...      6/11/2008
# 1      "Bennie Thompson actively cheer-led riots in t...       6/7/2022
# 2      Says Maggie Hassan was "out of state on 30 day...      5/18/2016
# 3      "BUSTED: CDC Inflated COVID Numbers, Accused o...       2/1/2021
# 4      "I'm the only (Republican) candidate that has ...      8/30/2015
# ...                                                  ...            ...
# ...

# %%
# Export to .csv
filtered.to_csv("politifact_filtered.csv", encoding='utf-8')
